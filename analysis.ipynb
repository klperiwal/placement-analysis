# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_microsoft= pd.read_csv('Microsoft.csv')
df_oracle= pd.read_csv('Oracle.csv')

# %%
df_microsoft
# Out:
#             Timestamp                  Email Address
# 0    07-07-2023 23:54        mehark.cs.21@nitj.ac.in  \
# 1    07-06-2023 17:27      gurnoorc.ce.21@nitj.ac.in
# 2    07-07-2023 22:22       aakriti.ec.21@nitj.ac.in
# 3    07-07-2023 16:20      harleenk.ec.21@nitj.ac.in
# 4    07-06-2023 23:12   anmoldeepsm.ec.21@nitj.ac.in
# ..                ...                            ...
# 339  07-07-2023 23:47        chetna.ec.21@nitj.ac.in
# 340  07-05-2023 21:04         manik.it.21@nitj.ac.in
# 341  07-06-2023 17:46       rajeshk.it.21@nitj.ac.in
# 342  07-06-2023 18:29  shivshankark.it.21@nitj.ac.in
# 343  07-06-2023 00:57        rohitk.it.21@nitj.ac.in
#
#                          Name  Roll Number                          Email ID
# 0                  Mehar Kaur     21103089           mehark.cs.21@nitj.ac.in  \
# 1             Gurnoor Chhabra     21102028         gurnoorc.ce.21@nitj.ac.in
# 2                     Aakriti     21104001          aakriti.ec.21@nitj.ec.in
# ...

# %%
df_microsoft.drop(columns=['Timestamp','Email Address','Name','Email ID','Course','Contact Number( Without +91)'],inplace=True)
df_microsoft.head()
# Out:
#    Roll Number  Gender                                     Branch
# 0     21103089    Male           Computer Science and Engineering  \
# 1     21102028    Male           Computer Science and Engineering
# 2     21104001  Female  Electronics and Communication Engineering
# 3     21104040  Female  Electronics and Communication Engineering
# 4     21104016    Male  Electronics and Communication Engineering
#
#    10th Percentage  12th Percentage  CGPA
# 0             98.8             99.0  9.26  \
# 1             93.0             86.0  9.22
# 2             96.8             95.6  9.18
# 3             93.6             96.8  9.18
# 4             94.0             88.4  9.16
#
#                                               Resume Placed
# 0  https://drive.google.com/open?id=19QL9BPgOa0H5...    YES
# 1  https://drive.google.com/open?id=1ggWPWiTUsm0l...     NO
# 2  https://drive.google.com/open?id=19rv5yoIPJu4r...     NO
# 3  https://drive.google.com/open?id=1_Rnf6j_9a4vs...     NO
# ...

# %%
df_microsoft.drop_duplicates(inplace=True)

# %%
df_microsoft.shape
# Out:
# (344, 8)

# %%
df_microsoft['Branch'].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Information Technology', 'Electrical Engineering'], dtype=object)

# %%
# The number of eligible candidates sitting for Microsoft internship
df_microsoft['Branch'].value_counts()
# Out:
# Branch
# Computer Science and Engineering             133
# Information Technology                        88
# Electronics and Communication Engineering     81
# Electrical Engineering                        42
# Name: count, dtype: int64

# %%
df_oracle
# Out:
#               Timestamp                       Email First Name   Last Name
# 0    7-14-2023 12:16:08     gunika.cs.20@nitj.ac.in    Gunika            .  \
# 1     7-14-2023 7:51:12    raghavg.ee.20@nitj.ac.in    Raghav        Gupta
# 2     7-14-2023 0:10:26     preeti.ec.20@nitj.ac.in    Preeti        Gulia
# 3    7-13-2023 22:23:36    puneets.ce.20@nitj.ac.in    Puneet        Singh
# 4    7-13-2023 22:25:16  vanshikas.ee.20@nitj.ac.in   Vanshika       Singh
# ..                  ...                         ...        ...         ...
# 454  7-13-2023 23:24:37   abhinavs.ec.20@nitj.ac.in   Abhinav      Saxena
# 455  7-14-2023 13:36:07  suvrojitm.ec.22@nitj.ac.in   Suvrojit       Mitra
# 456  7-13-2023 22:33:35    sameept.ee.20@nitj.ac.in     Sameep   Teggowal
# 457  7-13-2023 22:01:57     ankits.it.20@nitj.ac.in      Ankit        Sahu
# 458  7-13-2023 22:39:07   mahipalc.it.20@nitj.ac.in   Mahipal   Choudhary
#
# ...

# %%
df_oracle.drop(columns=['Timestamp','Email','First Name','Last Name','Email ID(personal ID)','NAME','Phone Number','College Name','Current degree'],inplace=True)

# %%
df_oracle.head()
# Out:
#    Gender Branch  Current CGPA  10th Percentage  12th Percentage  Roll no.
# 0  Female    CSE          9.49             98.8             99.0  20103061  \
# 1    Male     EE          9.29             93.0             86.0  20126045
# 2  Female    ECE          9.27             96.8             95.6  20104072
# 3    Male     IT          9.24             93.6             96.8  20102059
# 4  Female     EE          9.12             94.0             88.4  20126061
#
#                                               Resume Current Backlog Placed
# 0  https://drive.google.com/open?id=1fVwUcI9llIu-...              No    Yes
# 1  https://drive.google.com/open?id=1LrydmbXOg7KY...              No     No
# 2  https://drive.google.com/open?id=1seo56c-bmYww...              No     No
# 3  https://drive.google.com/open?id=1mHKRc5mvfjlR...              No     No
# 4  https://drive.google.com/open?id=1fqIi86XW8NQZ...              No     No

# %%
# df_oracle = df_oracle.iloc[:, 0:10]

# %%
df_oracle.dropna(inplace=True)

# %%
df_oracle
# Out:
#      Gender Branch  Current CGPA  10th Percentage  12th Percentage  Roll no.
# 0    Female    CSE          9.49             98.8             99.0  20103061  \
# 1      Male     EE          9.29             93.0             86.0  20126045
# 2    Female    ECE          9.27             96.8             95.6  20104072
# 3      Male     IT          9.24             93.6             96.8  20102059
# 4    Female     EE          9.12             94.0             88.4  20126061
# ..      ...    ...           ...              ...              ...       ...
# 454    Male    ECE          7.00             93.1             91.1  20104005
# 455    Male    ECE          7.00             95.0             74.6  22904008
# 456    Male     EE          7.00             92.0             88.0  20126051
# 457    Male     IT          7.00             91.0             79.4  20124015
# 458    Male     IT          7.00             78.0             66.5  20124055
#
# ...
